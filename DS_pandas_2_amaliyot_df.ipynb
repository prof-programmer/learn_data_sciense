# %% [markdown]
# <a href="https://colab.research.google.com/github/prof-programmer/learn_data_sciense/blob/main/DS_pandas_2_amaliyot_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # **DATA SCIENCE VA SUN'IY INTELLEKT PRAKTIKUM**
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# # **AMALIYOT**
# ## DataFrame

# %% [markdown]
# ### **1-mashq**. `Pandas` kutubxonasini `pd`, `numpy` kutubxonasini `np` deb chaqirib oling

# %%
# Javobni shuyerga yozing
import pandas as pd
import numpy as np

# %%
#@title **To'g'ri javob**
import pandas as pd
import numpy as np

# %% [markdown]
# ### **2-mashq.** Quyida ko'rsatilgan dataframeni yarating va `df` deb nomlang

# %%
# Javobni shuyerga yozing
viloyatlar = [
    "Andijon viloyati",
    "Buxoro viloyati",
    "Fargona viloyati",
    "Jizzax viloyati",
    "Xorazm viloyati",
    "Namangan viloyati",
    "Navoiy viloyati",
    "Qashqadaryo viloyati",
    "Qoraqalpogʻiston Respublikasi",
    "Samarqand viloyati",
    "Sirdaryo viloyati",
    "Surxondaryo viloyati",
    "Toshkent viloyati",
]
markazlar = [
    "Andijon shahri",
    "Buxoro shahri",
    "Fargona shahri",
    "Jizzax shahri",
    "Urganch shahri",
    "Namangan shahri",
    "Navoiy shahri",
    "Qarshi shahri",
    "Nukus shahri",
    "Samarqand shahri",
    "Guliston shahri",
    "Termiz shahri",
    "Nurafshon shahri",
]
maydonlar = [
    4200,
    39400,
    6800,
    20500,
    6300,
    7900,
    110800,
    28400,
    160000,
    16400,
    5100,
    20800,
    15300,
]
aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
]

data = {
    'Hudud': viloyatlar,
    'Markaz': markazlar,
    'Maydoni': maydonlar,
    'Aholisi': aholi
}

df = pd.DataFrame(data)
df
# Out:
#                             Hudud            Markaz  Maydoni  Aholisi
# 0                Andijon viloyati    Andijon shahri     4200  1899000
# 1                 Buxoro viloyati     Buxoro shahri    39400  1384700
# 2                Fargona viloyati    Fargona shahri     6800  2597000
# 3                 Jizzax viloyati     Jizzax shahri    20500   910500
# 4                 Xorazm viloyati    Urganch shahri     6300  1200000
# 5               Namangan viloyati   Namangan shahri     7900  1862000
# 6                 Navoiy viloyati     Navoiy shahri   110800   767500
# 7            Qashqadaryo viloyati     Qarshi shahri    28400  2029000
# 8   Qoraqalpogʻiston Respublikasi      Nukus shahri   160000  1200000
# 9              Samarqand viloyati  Samarqand shahri    16400  2322000
# 10              Sirdaryo viloyati   Guliston shahri     5100   648100
# 11           Surxondaryo viloyati     Termiz shahri    20800  1676000
# 12              Toshkent viloyati  Nurafshon shahri    15300  4450000

# %%
# @title **To'g'ri javob**
viloyatlar = [
    "Andijon viloyati",
    "Buxoro viloyati",
    "Fargona viloyati",
    "Jizzax viloyati",
    "Xorazm viloyati",
    "Namangan viloyati",
    "Navoiy viloyati",
    "Qashqadaryo viloyati",
    "Qoraqalpogʻiston Respublikasi",
    "Samarqand viloyati",
    "Sirdaryo viloyati",
    "Surxondaryo viloyati",
    "Toshkent viloyati",
]
markazlar = [
    "Andijon shahri",
    "Buxoro shahri",
    "Fargona shahri",
    "Jizzax shahri",
    "Urganch shahri",
    "Namangan shahri",
    "Navoiy shahri",
    "Qarshi shahri",
    "Nukus shahri",
    "Samarqand shahri",
    "Guliston shahri",
    "Termiz shahri",
    "Nurafshon shahri",
]
maydonlar = [
    4200,
    39400,
    6800,
    20500,
    6300,
    7900,
    110800,
    28400,
    160000,
    16400,
    5100,
    20800,
    15300,
]
aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
]
data = {
    "Hudud":viloyatlar,
    "Markaz":markazlar,
    "Maydoni":maydonlar,
    "Aholisi":aholi
}
df = pd.DataFrame(data)
df
# Out:
#                             Hudud            Markaz  Maydoni  Aholisi
# 0                Andijon viloyati    Andijon shahri     4200  1899000
# 1                 Buxoro viloyati     Buxoro shahri    39400  1384700
# 2                Fargona viloyati    Fargona shahri     6800  2597000
# 3                 Jizzax viloyati     Jizzax shahri    20500   910500
# 4                 Xorazm viloyati    Urganch shahri     6300  1200000
# 5               Namangan viloyati   Namangan shahri     7900  1862000
# 6                 Navoiy viloyati     Navoiy shahri   110800   767500
# 7            Qashqadaryo viloyati     Qarshi shahri    28400  2029000
# 8   Qoraqalpogʻiston Respublikasi      Nukus shahri   160000  1200000
# 9              Samarqand viloyati  Samarqand shahri    16400  2322000
# 10              Sirdaryo viloyati   Guliston shahri     5100   648100
# 11           Surxondaryo viloyati     Termiz shahri    20800  1676000
# 12              Toshkent viloyati  Nurafshon shahri    15300  4450000

# %% [markdown]
# ### **2-mashq.** Yuqoridagi df ning yuqorisidan 5 ta qator chiqaring

# %%
# Javobni shuyerga yozing
df.head()
# Out:
#               Hudud          Markaz  Maydoni  Aholisi
# 0  Andijon viloyati  Andijon shahri     4200  1899000
# 1   Buxoro viloyati   Buxoro shahri    39400  1384700
# 2  Fargona viloyati  Fargona shahri     6800  2597000
# 3   Jizzax viloyati   Jizzax shahri    20500   910500
# 4   Xorazm viloyati  Urganch shahri     6300  1200000

# %%
#@title **To'g'ri javob**
df.head()
# Out:
#                Hudud           Markaz  Maydoni  Aholisi
# 0   Andijon viloyati   Andijon shahri     4200  1899000
# 1    Buxoro viloyati    Buxoro shahri    39400  1384700
# 2  Fargʻona viloyati  Fargʻona shahri     6800  2597000
# 3    Jizzax viloyati    Jizzax shahri    20500   910500
# 4    Xorazm viloyati   Urganch shahri     6300  1200000

# %% [markdown]
# ### **3-mashq.** Yuqoridagi df dan tasodifiy 3 ta qator chiqaring

# %%
# Javobni shuyerga yozing
df.sample(3)
# Out:
#                Hudud           Markaz  Maydoni  Aholisi
# 5  Namangan viloyati  Namangan shahri     7900  1862000
# 1    Buxoro viloyati    Buxoro shahri    39400  1384700
# 0   Andijon viloyati   Andijon shahri     4200  1899000

# %%
#@title **To'g'ri javob**
df.sample(3)
# Out:
#                            Hudud          Markaz  Maydoni  Aholisi
# 0               Andijon viloyati  Andijon shahri     4200  1899000
# 3                Jizzax viloyati   Jizzax shahri    20500   910500
# 8  Qoraqalpogʻiston Respublikasi    Nukus shahri   160000  1200000

# %% [markdown]
# ### **4-mashq.** Yuqoridagi df ning 'Hudud' va 'Aholisi' ustinlarini alohida df ko'rinishida chiqaring

# %%
# Javobni shuyerga yozing
df2 = df[['Hudud', 'Aholisi']]
df2
# Out:
#                             Hudud  Aholisi
# 0                Andijon viloyati  1899000
# 1                 Buxoro viloyati  1384700
# 2                Fargona viloyati  2597000
# 3                 Jizzax viloyati   910500
# 4                 Xorazm viloyati  1200000
# 5               Namangan viloyati  1862000
# 6                 Navoiy viloyati   767500
# 7            Qashqadaryo viloyati  2029000
# 8   Qoraqalpogʻiston Respublikasi  1200000
# 9              Samarqand viloyati  2322000
# 10              Sirdaryo viloyati   648100
# 11           Surxondaryo viloyati  1676000
# 12              Toshkent viloyati  4450000

# %%
#@title **To'g'ri javob**
df[['Hudud','Aholisi']]
# Out:
#                             Hudud  Aholisi
# 0                Andijon viloyati  1899000
# 1                 Buxoro viloyati  1384700
# 2               Fargʻona viloyati  2597000
# 3                 Jizzax viloyati   910500
# 4                 Xorazm viloyati  1200000
# 5               Namangan viloyati  1862000
# 6                 Navoiy viloyati   767500
# 7            Qashqadaryo viloyati  2029000
# 8   Qoraqalpogʻiston Respublikasi  1200000
# 9              Samarqand viloyati  2322000
# 10              Sirdaryo viloyati   648100
# 11           Surxondaryo viloyati  1676000
# 12              Toshkent viloyati  4450000

# %% [markdown]
# ### **5-mashq.** Yuqoridagi df ning `Markaz` ustunini Series obyekti ko'rinishida chiqaring

# %%
# Javobni shuyerga yozing
df.Markaz # df['Markaz']
# Out:
# 0       Andijon shahri
# 1        Buxoro shahri
# 2       Fargona shahri
# 3        Jizzax shahri
# 4       Urganch shahri
# 5      Namangan shahri
# 6        Navoiy shahri
# 7        Qarshi shahri
# 8         Nukus shahri
# 9     Samarqand shahri
# 10     Guliston shahri
# 11       Termiz shahri
# 12    Nurafshon shahri
# Name: Markaz, dtype: object

# %%
#@title **To'g'ri javob**
df.Markaz
# Out:
# 0       Andijon shahri
# 1        Buxoro shahri
# 2      Fargʻona shahri
# 3        Jizzax shahri
# 4       Urganch shahri
# 5      Namangan shahri
# 6        Navoiy shahri
# 7        Qarshi shahri
# 8         Nukus shahri
# 9     Samarqand shahri
# 10     Guliston shahri
# 11       Termiz shahri
# 12    Nurafshon shahri
# Name: Markaz, dtype: object

# %% [markdown]
# ### **6-mashq.** Yuqoridagi df dan aholi soni 2 milliondan oshiq bo'lgan hududlarni chiqaring

# %%
# Javobni shuyerga yozing
df[df.Aholisi>2000000] # 2_000_000 deb yozsa ham boladi
# Out:
#                    Hudud            Markaz  Maydoni  Aholisi
# 2       Fargona viloyati    Fargona shahri     6800  2597000
# 7   Qashqadaryo viloyati     Qarshi shahri    28400  2029000
# 9     Samarqand viloyati  Samarqand shahri    16400  2322000
# 12     Toshkent viloyati  Nurafshon shahri    15300  4450000

# %%
#@title **To'g'ri javob**
df[df.Aholisi>2_000_000]
# Out:
#                    Hudud            Markaz  Maydoni  Aholisi
# 2      Fargʻona viloyati   Fargʻona shahri     6800  2597000
# 7   Qashqadaryo viloyati     Qarshi shahri    28400  2029000
# 9     Samarqand viloyati  Samarqand shahri    16400  2322000
# 12     Toshkent viloyati  Nurafshon shahri    15300  4450000

# %% [markdown]
# ### **7-mashq.** Yuqoridagi df dan maydoni 10000kv.km dan kichik bo'lgan hududlarni chiqaring

# %%
# Javobni shuyerga yozing
df[df.Maydoni<10_000]
# Out:
#                 Hudud           Markaz  Maydoni  Aholisi
# 0    Andijon viloyati   Andijon shahri     4200  1899000
# 2    Fargona viloyati   Fargona shahri     6800  2597000
# 4     Xorazm viloyati   Urganch shahri     6300  1200000
# 5   Namangan viloyati  Namangan shahri     7900  1862000
# 10  Sirdaryo viloyati  Guliston shahri     5100   648100

# %%
#@title **To'g'ri javob**
df[df.Maydoni<10000]
# Out:
#                 Hudud           Markaz  Maydoni  Aholisi
# 0    Andijon viloyati   Andijon shahri     4200  1899000
# 2    Fargona viloyati   Fargona shahri     6800  2597000
# 4     Xorazm viloyati   Urganch shahri     6300  1200000
# 5   Namangan viloyati  Namangan shahri     7900  1862000
# 10  Sirdaryo viloyati  Guliston shahri     5100   648100

# %% [markdown]
# ### **8-mashq.** Yuqoridagi df ning birinchi ustunini df ning indeksi sifatida ishlating
# Ishora:
# 1. Yoki df ni qayta yarating
# 2. Yoki `set_index()` metodidan foydalaning

# %%
# Javobni shuyerga yozing
# df.set_index('Hudud')
# df.set_index(df.columns[0]  - bu ko'rinishda ham yozsa bo'ladi
df.set_index(df.columns[0], inplace=True)
df.head()
# Out:
#                           Markaz  Maydoni  Aholisi
# Hudud
# Andijon viloyati  Andijon shahri     4200  1899000
# Buxoro viloyati    Buxoro shahri    39400  1384700
# Fargona viloyati  Fargona shahri     6800  2597000
# Jizzax viloyati    Jizzax shahri    20500   910500
# Xorazm viloyati   Urganch shahri     6300  1200000

# %%
#@title **To'g'ri javob**
df.set_index(df.columns[0], inplace=True)
df.head()
# Out:
#                           Markaz  Maydoni  Aholisi
# Hudud
# Andijon viloyati  Andijon shahri     4200  1899000
# Buxoro viloyati    Buxoro shahri    39400  1384700
# Fargona viloyati  Fargona shahri     6800  2597000
# Jizzax viloyati    Jizzax shahri    20500   910500
# Xorazm viloyati   Urganch shahri     6300  1200000

# %% [markdown]
# ### **9-mashq.** Yuqoridagi df dan, Aholisi 2 milliondan oshiq hududlar orasida Samarqand viloyati bor yoki yo'qligini tekshiring

# %%
# Javobni shuyerga yozing
'Samarqand viloyati' in df[df.Aholisi > 2000000].index #indeksda bo'lgani uchun .index yozildi shekilli
# Out:
# True

# %%
#@title **To'g'ri javob**
"Samarqand viloyati" in df[df.Aholisi>2_000_000].index
# Out:
# True

# %% [markdown]
# ### **10-mashq.**  Yuqoridagi df dan faqatgina Andijon, Farg'ona va Namangan viloyatlarini ajratib ko'rsating

# %%
# Javobni shuyerga yozing
df.loc[['Andijon viloyati', 'Fargona viloyati', 'Namangan viloyati']] # df.loc dan foydalanish kerak indeks orqali izlash uchun
# Out:
#                             Markaz  Maydoni  Aholisi
# Hudud
# Andijon viloyati    Andijon shahri     4200  1899000
# Fargona viloyati    Fargona shahri     6800  2597000
# Namangan viloyati  Namangan shahri     7900  1862000

# %%
#@title **To'g'ri javob**
df.loc[["Andijon viloyati","Fargona viloyati","Namangan viloyati"]]
# Out:
#                             Markaz  Maydoni  Aholisi
# Hudud
# Andijon viloyati    Andijon shahri     4200  1899000
# Fargona viloyati    Fargona shahri     6800  2597000
# Namangan viloyati  Namangan shahri     7900  1862000

# %% [markdown]
# ### **11-mashq.**  Yuqoridagi df dan Samarqanda va Toshkent viloyatlarining aholisi va maydonini alohida df ko'rinishida chiqaring

# %%
# Javobni shuyerga yozing
df2 = df.loc[['Toshkent viloyati', 'Samarqand viloyati'], ['Maydoni', 'Aholisi']]
df2
# Out:
#                     Maydoni  Aholisi
# Hudud
# Toshkent viloyati     15300  4450000
# Samarqand viloyati    16400  2322000

# %%
#@title **To'g'ri javob**
df.loc[['Toshkent viloyati','Samarqand viloyati'],['Maydoni','Aholisi']]
# Out:
#                     Maydoni  Aholisi
# Hudud
# Toshkent viloyati     15300  4450000
# Samarqand viloyati    16400  2322000

# %% [markdown]
# ### **12-mashq.**  Yuqoridagi df dan yangi df_new DataFrame yarating. Yangi dataframega faqatgina aholisi 1.5mln dan kam bo'lgan hududlarni ko'chiring.

# %%
# Javobni shuyerga yozing
df_new = df[df.Aholisi < 1_500_000]
df_new
# Out:
#                                         Markaz  Maydoni  Aholisi
# Hudud
# Buxoro viloyati                  Buxoro shahri    39400  1384700
# Jizzax viloyati                  Jizzax shahri    20500   910500
# Xorazm viloyati                 Urganch shahri     6300  1200000
# Navoiy viloyati                  Navoiy shahri   110800   767500
# Qoraqalpogʻiston Respublikasi     Nukus shahri   160000  1200000
# Sirdaryo viloyati              Guliston shahri     5100   648100

# %%
#@title **To'g'ri javob**
df_new = df[df.Aholisi<1_500_000]
df_new
# Out:
#                                         Markaz  Maydoni  Aholisi
# Hudud
# Buxoro viloyati                  Buxoro shahri    39400  1384700
# Jizzax viloyati                  Jizzax shahri    20500   910500
# Xorazm viloyati                 Urganch shahri     6300  1200000
# Navoiy viloyati                  Navoiy shahri   110800   767500
# Qoraqalpogʻiston Respublikasi     Nukus shahri   160000  1200000
# Sirdaryo viloyati              Guliston shahri     5100   648100

# %% [markdown]
# ### **13-mashq.**  Yangi df qatorlari orasida Navoiy, Namangan va Xorazm viloyatlari borligini tekshiring

# %%
# Javobni shuyerga yozing
viloyatlar = ['Navoiy viloyati', 'Namangan viloyati', 'Xorazmi viloyati']
viloyatlar in df_new.index # xato
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-4a1e2ed4de4b> in <cell line: 3>()
#       1 # Javobni shuyerga yozing
#       2 viloyatlar = ['Navoiy viloyati', 'Namangan viloyati', 'Xorazmi viloyati']
# ----> 3 viloyatlar in df_new.index
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    5287         False
#    5288         """
# -> 5289         hash(key)
#    5290         try:
#    5291             return key in self._engine
#
# TypeError: unhashable type: 'list'

# %%
#@title **To'g'ri javob**
pd.Index(['Navoiy viloyati','Namangan viloyati','Xorazm viloyati']).isin(df_new.index)
# Out:
# array([ True, False,  True])

# %% [markdown]
# ### **14-mashq.**  Aholisi 1milliondan ko'p, lekin maydoni 10000kv.km dan kam hududlarni chiqaring

# %%
# Javobni shuyerga yozing
df[df.Aholisi > 1000000 and df.Maydoni < 10000] # xato ekan
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-1e87fc3dd1ba> in <cell line: 2>()
#       1 # Javobni shuyerga yozing
# ----> 2 df[df.Aholisi > 1000000 and df.Maydoni < 10000]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#@title **To'g'ri javob**
df[(df.Aholisi>1_000_000) & (df.Maydoni<10000)]
# Out:
#                             Markaz  Maydoni  Aholisi
# Hudud
# Andijon viloyati    Andijon shahri     4200  1899000
# Fargona viloyati    Fargona shahri     6800  2597000
# Xorazm viloyati     Urganch shahri     6300  1200000
# Namangan viloyati  Namangan shahri     7900  1862000

# %% [markdown]
# ### **15-mashq.**  Aholisi 1milliondan kam, lekin maydoni 10000kv.km dan ko'p hududlarni chiqaring

# %%
# Javobni shuyerga yozing
df[(df.Aholisi < 1000000) & (df.Maydoni > 10000)]
# Out:
#                         Markaz  Maydoni  Aholisi
# Hudud
# Jizzax viloyati  Jizzax shahri    20500   910500
# Navoiy viloyati  Navoiy shahri   110800   767500

# %%
#@title **To'g'ri javob**
df[(df.Aholisi<1_000_000) & (df.Maydoni>10000)]
# Out:
#                         Markaz  Maydoni  Aholisi
# Hudud
# Jizzax viloyati  Jizzax shahri    20500   910500
# Navoiy viloyati  Navoiy shahri   110800   767500

# %% [markdown]
# ### **16-mashq.**  Yuqoridagi df dan `Markaz` ustunini tashlab yuboring

# %%
# Javobni shuyerga yozing
df.drop(['Markaz'], axis=1)
# Out:
#                                Maydoni  Aholisi
# Hudud
# Andijon viloyati                  4200  1899000
# Buxoro viloyati                  39400  1384700
# Fargona viloyati                  6800  2597000
# Jizzax viloyati                  20500   910500
# Xorazm viloyati                   6300  1200000
# Namangan viloyati                 7900  1862000
# Navoiy viloyati                 110800   767500
# Qashqadaryo viloyati             28400  2029000
# Qoraqalpogʻiston Respublikasi   160000  1200000
# Samarqand viloyati               16400  2322000
# Sirdaryo viloyati                 5100   648100
# Surxondaryo viloyati             20800  1676000
# Toshkent viloyati                15300  4450000

# %%
#@title **To'g'ri javob**
df.drop(['Markaz'], axis=1)
# Out:
#                                Maydoni  Aholisi
# Hudud
# Andijon viloyati                  4200  1899000
# Buxoro viloyati                  39400  1384700
# Fargona viloyati                  6800  2597000
# Jizzax viloyati                  20500   910500
# Xorazm viloyati                   6300  1200000
# Namangan viloyati                 7900  1862000
# Navoiy viloyati                 110800   767500
# Qashqadaryo viloyati             28400  2029000
# Qoraqalpogʻiston Respublikasi   160000  1200000
# Samarqand viloyati               16400  2322000
# Sirdaryo viloyati                 5100   648100
# Surxondaryo viloyati             20800  1676000
# Toshkent viloyati                15300  4450000

# %% [markdown]
# ### **17-mashq.**  Yuqoridagi df dan Sirdaryo viloyati aholisini chiqaring

# %%
# Javobni shuyerga yozing
df[['Sirdaryo viloyati'], ['Aholisi']] # xato , df.at['Sirdaryo viloyati','Aholisi'] deb yozish kerak
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['Sirdaryo viloyati'], ['Aholisi'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-26-b549fbaea8e0> in <cell line: 2>()
#       1 # Javobni shuyerga yozing
# ----> 2 df[['Sirdaryo viloyati'], ['Aholisi']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3807                 #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808                 #  the TypeError.
# -> 3809                 self._check_indexing_error(key)
#    3810                 raise
#    3811
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _check_indexing_error(self, key)
#    5923             # if key is not a scalar, directly raise an error (the code below
#    5924             # would convert to numpy arrays and raise later any way) - GH29926
# -> 5925             raise InvalidIndexError(key)
#    5926
#    5927     @cache_readonly
#
# InvalidIndexError: (['Sirdaryo viloyati'], ['Aholisi'])

# %%
#@title **To'g'ri javob**
df.at['Sirdaryo viloyati','Aholisi']
# Out:
# 648100

# %% [markdown]
# ### **18-mashq.**  Yuqoridagi df dan Buxoro viloyati maydonini chiqaring

# %%
# Javobni shuyerga yozing
df.at['Buxoro viloyati', 'Maydoni']
# Out:
# 39400

# %%
#@title **To'g'ri javob**
df.at['Buxoro viloyati','Maydoni']
# Out:
# 39400

# %% [markdown]
# ### **19-mashq.**  Yuqoridagi df dan Toshkent viloyati maydoni O'zbekiston Respublikasining necha fozini tashkil qilishini toping

# %%
# Javobni shuyerga yozing
df_tashkent = df.at['Toshkent viloyati', 'Maydoni']
df_sum = sum(df.Maydoni)
df_percent = int(df_tashkent/df_sum * 100)
print(f'Toshkent viloyati maydoni: {df_tashkent} kv.km')
print(f"O'zbektiston Respublikasi maydoni: {df_sum} kv.km")
print(f"Toshkent viloyati maydoni O'zbekiston respublikasining {df_percent}% ni tashkil qiladi")
# Out:
# Toshkent viloyati maydoni: 15300 kv.km
# O'zbektiston Respublikasi maydoni: 441900 kv.km
# Toshkent viloyati maydoni O'zbekiston respublikasining 3% ni tashkil qiladi

# %%
#@title **To'g'ri javob**
tosh_area = df.at['Toshkent viloyati','Maydoni']
uzb_area = sum(df.Maydoni) # yoki
# uzb_area = df.Maydoni.sum()
print(f"Toshkent viloyati maydoni: {tosh_area} kv.km")
print(f"O'zbekiston Respublikasi maydoni: {uzb_area} kv.km")
print(f"Toshkent viloyati maydoni O'zbekiston respublikasining {round(tosh_area/uzb_area*100)}% ni tashkil qiladi")
# Out:
# Toshkent viloyati maydoni: 15300 kv.km
# O'zbekiston Respublikasi maydoni: 441900 kv.km
# Toshkent viloyati maydoni O'zbekiston respublikasining 3% ni tashkil qiladi

# %% [markdown]
# ### **20-mashq.**  Yuqoridagi df dan Toshkent viloyati aholisi O'zbekiston Respublikasining necha fozini tashkil qilishini toping

# %%
# Javobni shuyerga yozing
toshkent_aholisi = df.at['Toshkent viloyati', 'Aholisi']
uzb_aholisi = sum(df.Aholisi)
toshkent_foizda = int(toshkent_aholisi/uzb_aholisi * 100)
print(f'Toshkent viloyati aholisi: {toshkent_aholisi} kv.km')
print(f"O'zbektiston Respublikasi maydoni: {uzb_aholisi} kv.km")
print(f"Toshkent viloyati maydoni O'zbekiston respublikasining {toshkent_foizda}% ni tashkil qiladi")
# Out:
# Toshkent viloyati aholisi: 4450000 kv.km
# O'zbektiston Respublikasi maydoni: 22945800 kv.km
# Toshkent viloyati maydoni O'zbekiston respublikasining 19% ni tashkil qiladi

# %%
#@title **To'g'ri javob**
tosh_area = df.at['Toshkent viloyati','Aholisi']
uzb_area = sum(df.Aholisi) # yoki
# uzb_area = df.Maydoni.sum()
print(f"Toshkent viloyati aholisi: {tosh_area} kishi")
print(f"O'zbekiston Respublikasi aholisi: {uzb_area} kishi")
print(f"Toshkent viloyati aholisi O'zbekiston respublikasining {round(tosh_area/uzb_area*100)}% ni tashkil qiladi")
# Out:
# Toshkent viloyati aholisi: 4450000 kishi
# O'zbekiston Respublikasi aholisi: 22945800 kishi
# Toshkent viloyati aholisi O'zbekiston respublikasining 19% ni tashkil qiladi
